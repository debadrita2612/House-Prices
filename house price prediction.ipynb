# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import linear_model
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df= pd.read_csv(r'C:\Users\KIIT\Untitled Folder 4\house-prices.csv')

# %%
df.head(30)
# Out:
#     Home   Price  SqFt  Bedrooms  Bathrooms  Offers Brick Neighborhood
# 0      1  114300  1790         2          2       2    No         East
# 1      2  114200  2030         4          2       3    No         East
# 2      3  114800  1740         3          2       1    No         East
# 3      4   94700  1980         3          2       3    No         East
# 4      5  119800  2130         3          3       3    No         East
# 5      6  114600  1780         3          2       2    No        North
# 6      7  151600  1830         3          3       3   Yes         West
# 7      8  150700  2160         4          2       2    No         West
# 8      9  119200  2110         4          2       3    No         East
# 9     10  104000  1730         3          3       3    No         East
# 10    11  132500  2030         3          2       3   Yes         East
# 11    12  123000  1870         2          2       2   Yes         East
# ...

# %%
x =df.iloc[:,2].values
y = df.iloc[:,1].values
x,y
# Out:
# (array([1790, 2030, 1740, 1980, 2130, 1780, 1830, 2160, 2110, 1730, 2030,
#         1870, 1910, 2150, 2590, 1780, 2190, 1990, 1700, 1920, 1790, 2000,
#         1690, 1820, 2210, 2290, 2000, 1700, 1600, 2040, 2250, 1930, 2250,
#         2280, 2000, 2080, 1880, 2420, 1720, 1740, 1560, 1840, 1990, 1920,
#         1940, 1810, 1990, 2050, 1980, 1700, 2100, 1860, 2150, 2100, 1650,
#         1720, 2190, 2240, 1840, 2090, 2200, 1610, 2220, 1910, 1860, 1450,
#         2210, 2040, 2140, 2080, 1950, 2160, 1650, 2040, 2140, 1900, 1930,
#         2280, 2130, 1780, 2190, 2140, 2050, 2410, 1520, 2250, 1900, 1880,
#         1930, 2010, 1920, 2150, 2110, 2080, 2150, 1970, 2440, 2000, 2060,
#         2080, 2010, 2260, 2410, 2440, 1910, 2530, 2130, 1890, 1990, 2110,
#         1710, 1740, 1940, 2000, 2010, 1900, 2290, 1920, 1950, 1920, 1930,
#         1930, 2060, 1900, 2160, 2070, 2020, 2250], dtype=int64),
#  array([114300, 114200, 114800,  94700, 119800, 114600, 151600, 150700,
# ...

# %%
plt.scatter(x,y)
plt.title("Sqft X price")
# Out:
# Text(0.5, 1.0, 'Sqft X price')

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 1/3, random_state = 0)
x_test=x_test.reshape(-1,1)
x_train=x_train.reshape(-1,1)

# %%
linreg_model=linear_model.LinearRegression()
linreg_model.fit(x_train,y_train)
linreg_model_pred=lin_reg.predict(x_test)
print("Coefficients:\n",linreg_model.coef_)
print("Intercept:\n",linreg_model.intercept_)
print("Mean squared error: %.2f"
      % mean_squared_error(y_test, linreg_model_pred))
print('Variance score: %.2f' % r2_score(y_test,  linreg_model_pred))
# Out:
# Coefficients:
#  [75.08653035]
# Intercept:
#  -19184.65810816211
# Mean squared error: 507766565.23
# Variance score: 0.13

# %%
plt.scatter(x_test, y_test, color = 'green')
plt.plot(x_test,  linreg_model_pred, color = 'blue')
plt.title('Sqft vs Price(Test set)')
plt.xlabel('Sqft')
plt.ylabel('Price')
plt.show()
